# %%
#Import modules
import pandas as panda
import matplotlib
from matplotlib import pyplot as plot
from datetime import datetime
import numpy as np

# %%
#Avganger fra Jernbanetorget

plot.hist(avganger.Holdeplass_Til, bins=10, rwidth=1)
plot.xlabel('Til holdeplass')
plot.ylabel('Antall avnganger')
plot.show()

# %%
linjerCount = dataframe[dataframe.Kommune == "Bærum"]
linjerCount.shape
# Out:
# (724, 17)

# %%
#Antall passasjerer på forskjellige linjer i bærum

plot.figure(figsize=(18,5))
plot.scatter(linjerCount.Linjenavn, linjerCount.Passasjerer_Ombord)
plot.xlabel('Linjenummer')
plot.ylabel('Antall passasjerer')
plot.show()

# %%
passCount = dataframe[dataframe.Linjenavn == "140E"]
passCount.shape
# Out:
# (5, 17)

# %%
#Antall passasjerer på linje 140E 

plot.figure(figsize=(20,8))
plot.plot(passCount.TurId, passCount.Passasjerer_Ombord)
plot.xlabel('Avganger linje 140E')
plot.ylabel('Antall pasasjerer')
plot.show()

# %%
#Hvor stor kapasitet det er på hver buss fra Jernbanetorget

avganger = dataframe[dataframe.Holdeplass_Fra.str.startswith("Jernbanetorget")] 

labels = avganger.Linjenavn

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars


fig, ax = plot.subplots()
rects1 = ax.bar(x - width/2, avganger.Passasjerer_Ombord, width, label='Passasjerer')
rects2 = ax.bar(x + width/2, avganger.Kjøretøy_Kapasitet, width, label='Kapasitet')

ax.set_ylabel('Antall mennesker')
ax.set_title('Forskjell')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

plot.show()

# %%
#Antall avganger pr område på en spesefik dato

avgangerDato = dataframe[dataframe.Dato=="01/06/2020"]


plot.hist(avgangerDato.Område, bins=5, rwidth=1.8)
plot.xlabel('Avganger i området')
plot.ylabel('Antall pavganger')
plot.show()

# %%
#Høyeste antall passasjerer på rute 

thresold_max = dataframe['Passasjerer_Ombord'].quantile(0.99)
passCount = dataframe[dataframe.Passasjerer_Ombord > thresold_max]

passCount
# Out:
#                                 TurId        Dato  Fylke    Område  \
# 33    43008-2020-06-09T13:55:00+02:00  09/06/2020  Viken   Nordøst
# 75    40001-2020-06-13T16:51:00+02:00  13/06/2020  Viken   Nordøst
# 192   36505-2020-08-19T07:50:00+02:00  19/08/2020  Viken   Nordøst
# 288   10002-2020-07-09T18:30:00+02:00  09/07/2020   Oslo   Nordøst
# 668   42912-2020-08-19T14:25:00+02:00  19/08/2020  Viken   Nordøst
# 693   10013-2020-07-17T17:30:00+02:00  17/07/2020   Oslo   Nordøst
# 898   10009-2020-07-31T07:30:00+02:00  31/07/2020   Oslo   Nordøst
# 1159  30023-2020-06-10T14:11:00+02:00  10/06/2020   Oslo   Nordøst
# 1187  15005-2020-08-03T14:39:00+02:00  03/08/2020  Viken      Vest
# 1195   3101-2020-08-08T11:12:00+02:00  08/08/2020   Oslo   Nordøst
# 1506  30004-2020-08-26T07:11:00+02:00  26/08/2020   Oslo   Nordøst
# 1639  10006-2020-08-01T17:30:00+02:00  01/08/2020  Viken   Nordøst
# 1667  10010-2020-06-24T15:44:00+02:00  24/06/2020   Oslo   Nordøst
# ...

# %%
#Laveste antall passasjerer på rute

thresold_min = dataframe['Passasjerer_Ombord'].quantile(0.01)
passCount = dataframe[dataframe.Passasjerer_Ombord < thresold_min]

passCount
# Out:
#                                 TurId        Dato  Fylke    Område  \
# 87    55006-2020-07-16T20:00:00+02:00  16/07/2020  Viken       Sør
# 205   39026-2020-06-08T09:24:00+02:00  08/06/2020  Viken   Nordøst
# 253   45502-2020-06-25T15:48:00+02:00  25/06/2020  Viken   Nordøst
# 337   12501-2020-06-02T12:33:00+02:00  02/06/2020  Viken   Nordøst
# 382   14002-2020-08-20T15:17:00+02:00  20/08/2020  Viken      Vest
# 414   30009-2020-07-29T18:50:00+02:00  29/07/2020  Viken   Nordøst
# 553    4101-2020-08-06T15:27:00+02:00  06/08/2020   Oslo      Vest
# 563    3101-2020-06-26T05:24:00+02:00  26/06/2020  Viken      Vest
# 591   21002-2020-08-26T15:03:00+02:00  26/08/2020  Viken      Vest
# 680    4101-2020-08-16T19:27:00+02:00  16/08/2020   Oslo      Vest
# 881   12007-2020-08-21T07:56:00+02:00  21/08/2020  Viken   Nordøst
# 1053  24006-2020-07-11T14:02:00+02:00  11/07/2020  Viken      Vest
# 1127  30009-2020-08-24T23:03:00+02:00  24/08/2020   Oslo  Indre By
# ...

# %%
#Holdeplasser med flest avganger og færrest avganger

avgangerCount = dataframe['Holdeplass_Fra'].value_counts()

avgangerCount
# Out:
# Jenseberget                        39
# Knatten (Solheimsveien)            38
# Ahus                               36
# Jonas Lies gate                    35
# Kloppaveien                        29
#                                    ..
# Hasle  (mot Helsfyr) (plf D)        1
# Røsslyngveien                       1
# Aurskog stasjon                     1
# Tøyen stasjon  (mot Ensjøveien)     1
# Bråtasletta (mot Oslo)              1
# Name: Holdeplass_Fra, Length: 1632, dtype: int64

# %%
#Gjennomsnittlige avganger fra hver holdeplass

avgangerCount = dataframe['Holdeplass_Fra'].value_counts()

print(avgangerCount.sum()/avgangerCount.shape[0])
# Out:
# 3.676470588235294

# %%
#Avganger med flest passasjerer

thresold_max = dataframe['Passasjerer_Ombord'].quantile(0.90)

passCount=dataframe[(dataframe['Passasjerer_Ombord']>thresold_max)]

passCount
# Out:
#                                 TurId        Dato  Fylke    Område  \
# 33    43008-2020-06-09T13:55:00+02:00  09/06/2020  Viken   Nordøst
# 75    40001-2020-06-13T16:51:00+02:00  13/06/2020  Viken   Nordøst
# 93    55002-2020-06-29T21:00:00+02:00  29/06/2020  Viken   Nordøst
# 116    3103-2020-06-01T07:14:00+02:00  01/06/2020   Oslo  Indre By
# 120   45007-2020-06-15T13:36:00+02:00  15/06/2020  Viken   Nordøst
# ...                               ...         ...    ...       ...
# 5909  55010-2020-06-17T13:35:00+02:00  17/06/2020  Viken       Sør
# 5929  25021-2020-08-05T06:58:00+02:00  05/08/2020  Viken      Vest
# 5932  43112-2020-06-18T07:29:00+02:00  18/06/2020  Viken   Nordøst
# 5944  40033-2020-08-24T06:21:00+02:00  24/08/2020  Viken   Nordøst
# 5970  30011-2020-06-14T22:14:00+02:00  14/06/2020  Viken   Nordøst
#
#           Kommune                                Holdeplass_Fra  \
# 33       Eidsvoll                                         Myrer
# ...

# %%
#Gjennomsnittlig passasjerer pr tur

turCounter = dataframe['TurId']
avgPass = dataframe['Passasjerer_Ombord'].sum()
print(avgPass/turCounter.shape[0])
# Out:
# 4.512833333333333
